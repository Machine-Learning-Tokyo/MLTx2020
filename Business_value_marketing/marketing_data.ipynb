# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('camera_1.csv', encoding='utf8')

# %%
data
# Out:
#      Time  Face_count  Age  Male  Female  Emotion
# 0    7:00           0    0     0       0     none
# 1    7:15           0    0     0       0     none
# 2    7:30           0    0     0       0     none
# 3    7:45           0    0     0       0     none
# 4    8:00          30   20    24       6    happy
# 5    8:15          30   20    24       6    happy
# 6    8:30          30   20    24       6  neutral
# 7    8:45          50   20    40      10    happy
# 8    9:00          60   20    48      12  neutral
# 9    9:15         100   20    75      25  neutral
# 10   9:30         150   20   105      45  neutral
# 11   9:45         250   20   175      75    angry
# 12  10:00         250   20   175      75  neutral
# 13  10:15         170   20   105      65  neutral
# 14  10:30         170   40   105      65  neutral
# 15  10:45         160   40    96      24    happy
# 16  11:00         120   40    96      24    happy
# 17  11:15         120   40    96      24    happy
# ...

# %%
print(data.groupby('Emotion').size())
# %matplotlib inline
import matplotlib as plt
data['Emotion'].value_counts().plot(kind="barh", cmap='Blues_r')
# Out:
# Emotion
# angry       3
# happy      28
# neutral    35
# none        7
# dtype: int64

# %%
print("The average age on Day 1 is %s" % data['Age'].mean())
# Out:
# The average age on Day 1 is 30.958904109589042

# %%
data.plot(subplots=True)
data.plot(figsize=(18,8))
